# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('a1_train.csv')

plot = sns.scatterplot(data=df, x='AttrX', y='AttrY', hue='Class')

# %% [markdown]
# ### 1.2 and 1.2a
#
# ![Boundaries](boundaries.png)
#
#
# There is a close to infinite number of potential boundaries but for this instance , the red boundary will be the best suited for unseen data, due to how it is approximately in the middle of the two classes.

# %% [markdown]
# ![weka1](weka1.png)
# ![weka2](weka2.png)

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()

from sklearn import linear_model
reg = linear_model.LinearRegression()

X = df.AttrX.values
y = df.AttrY.values
X = X.reshape(len(X), 1)
#y = y.reshape(len(y), 1)

reg.fit(X,y)
reg.coef_
# Out:
# array([0.56860158])
